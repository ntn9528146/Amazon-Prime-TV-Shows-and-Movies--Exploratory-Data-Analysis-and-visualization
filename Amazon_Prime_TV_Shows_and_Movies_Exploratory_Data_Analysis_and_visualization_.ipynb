# %% [markdown]
# <a href="https://colab.research.google.com/github/ntn9528146/Amazon-Prime-TV-Shows-and-Movies--Exploratory-Data-Analysis-and-visualization/blob/main/Amazon_Prime_TV_Shows_and_Movies_Exploratory_Data_Analysis_and_visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# Amazon Prime TV Shows and Movies -Exploratory Data Analysis and visualization

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**Nitin Tripathi
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Project Overview & Objectives
# The project seeks to analyze Amazon Prime Video’s content catalog—encompassing both movies and TV shows—to uncover insights on metadata such as content types, genres, release trends, durations, ratings, and countries of origin. The analysis aims to inform strategic decisions in content planning and audience engagement.
#
# Objectives:
# Understand the distribution of Movies vs. TV Shows
#
# Track release/year trends and spikes in content additions
#
# Identify dominant genres and ratings
#
# Analyze content origins by country
#
# Feature engineering (e.g., separating decades, extracting actors/directors) for deeper insight.
#
# Dataset & Technologies:
#
# This data set was created to list all shows available on Amazon Prime streaming, and analyze the data to find interesting facts. This dataset has data available in the United States.
#
# This dataset has two files containing the titles (titles.csv) and the cast (credits.csv) for the title.
#
# This dataset contains +9k unique titles on Amazon Prime with 15 columns containing their information, including:
#
# id: The title ID on JustWatch.
# title: The name of the title.
# show_type: TV show or movie.
# description: A brief description.
# release_year: The release year.
# age_certification: The age certification.
# runtime: The length of the episode (SHOW) or movie.
# genres: A list of genres.
# production_countries: A list of countries that produced the title.
# seasons: Number of seasons if it's a SHOW.
# imdb_id: The title ID on IMDB.
# imdb_score: Score on IMDB.
# imdb_votes: Votes on IMDB.
# tmdb_popularity: Popularity on TMDB.
# tmdb_score: Score on TMDB.
# And over +124k credits of actors and directors on Amazon Prime titles with 5 columns containing their information:
#
# person_ID: The person ID on JustWatch.
# id: The title ID on JustWatch.
# name: The actor or director's name.
# character_name: The character name.
# role: ACTOR or DIRECTOR.
# Problem Statement
#
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.
#
# Main Libraries to be used:
#
# Pandas for data manipulation, aggregation
# Matplotlib and Seaborn for visualization and behavior with respect to the target variable. Use at least 5 different visualizations.
# NumPy for computationally efficient operations.
#
# Tech Stack:
# Python as core language
#
# Libraries: Pandas, NumPy, Matplotlib, Seaborn for data manipulation and visualization
#
# Development environments: Google Colab
#
# Typical Workflow
# Data Loading & Cleaning
#
# Import datasets (CSV/JSON)
#
# Handle missing values (e.g., fill with "Unknown" or mode)
# Data type corrections (e.g., converting lists in genre/country fields)
# Exploratory Data Analysis
#
# Plotting:
#
# Bar/pie charts: content type distribution, genre breakdown, ratings distribution
# Year trend line chart to show content release over time
# Heatmaps or correlation plots to detect relationships
#
# Word clouds for titles, casts, directors (visualizing common terms)
# Key Insights & Business Implications
#
# Confirm that Movies generally outnumber TV Shows significantly
# Note content release peaks—often post‑2015 or a surge around 2019–2020
# Identify top genres (e.g., Drama, Comedy, Action)
# Highlight leading content production countries (e.g., USA, India, UK)
#
# Recognize mature audience ratings (e.g., TV-MA, R) as prevalent
#
# Extension Opportunities
#
# Add actor/director frequency or network analysis
#
# Build interactive dashboards with Power BI or Plotly
#
# Perform user preference segmentation, or propose a recommendation system pipeline
#
# Capstone Project Structure
# Section	Description
# 1. Introduction	Objective, data overview, methodology
# 2. Data Ingestion & Cleaning	Loading, handling missing data, corrections
# 3. Feature Engineering	Transforming columns, crafting indicators
# 4. Exploratory Visuals	Charts on content type, trends, genres, countries
# 5. Analytical Insights	Major findings with business context
# 6. Extensions	Next steps: dashboards, deeper modeling
# 7. Conclusion	Summary of findings and recommendations
#
# Summary
# This capstone EDA project offers a crisp, insightful, Python‑based exploration of Amazon Prime’s content, leveraging standard tech stacks and delivering business-relevant findings. It’s easily adaptable—perfect for showcasing data skills, storytelling, and strategic insight.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ** Problem Statement:-
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To empower strategic decision-making for streaming platforms by extracting actionable insights from Amazon Prime Video’s content metadata—emphasizing content optimization, audience engagement, and competitive advantage.
#
# Key Objectives Breakdown:
# Content Curation & Acquisition Strategy
# Understand genre popularity, content types (Movies vs. TV Shows), and regional production patterns to guide future acquisitions and content investments.
#
#
# Viewer Engagement & Personalization
# Analyze content characteristics—such as ratings, release trends, and duration—to enhance recommendation systems and improve viewer satisfaction and retention.
#
#
# Market Positioning & Competitive Benchmarking
# Evaluate Amazon Prime Video’s content mix relative to market rivals and identify gaps or emerging trends to better differentiate offerings.
#
#
# Regional & Demographic Strategy
# Leverage insights into country-specific content contributions and rating tiers to tailor regional strategies and target demographic segments effectively.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load Dataset
credits=pd.read_csv("/content/credits.csv")
titles=pd.read_csv("/content/titles.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
credits.head()

# %%
titles.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
credits.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
credits.info()

# %%
titles.info()

# %% [markdown]
# Merging two dataset that is credits and titles.
# based: common column -id

# %%
#after merging creting new dataset that is "amz"
amz=credits.merge(titles,on='id')

# %%
#dataset amz info
amz.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
amz.duplicated().sum()

# %%
amz.drop_duplicates(inplace=True)

# %%
amz.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
amz.isnull().sum()

# %%
#fill NA value with "NOT Available"
amz.age_certification.fillna('Not Available',inplace=True)

# %%
# Visualizing the missing values
#after reslove NA value check that no value is missing
amz.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This data set was created to list all shows available on Amazon Prime streaming, and analyze the data to find interesting facts. This dataset has data available in the United States.
#
# This dataset has two files containing the titles (titles.csv) and the cast (credits.csv) for the title.
#
# This dataset contains +9k unique titles on Amazon Prime with 15 columns containing their information, including:
#
# id: The title ID on JustWatch.
# title: The name of the title.
# show_type: TV show or movie.
# description: A brief description.
# release_year: The release year.
# age_certification: The age certification.
# runtime: The length of the episode (SHOW) or movie.
# genres: A list of genres.
# production_countries: A list of countries that produced the title.
# seasons: Number of seasons if it's a SHOW.
# imdb_id: The title ID on IMDB.
# imdb_score: Score on IMDB.
# imdb_votes: Votes on IMDB.
# tmdb_popularity: Popularity on TMDB.
# tmdb_score: Score on TMDB.
# And over +124k credits of actors and directors on Amazon Prime titles with 5 columns containing their information:
#
# person_ID: The person ID on JustWatch.
# id: The title ID on JustWatch.
# name: The actor or director's name.
# character_name: The character name.
# role: ACTOR or DIRECTOR.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
amz.columns

# %%
# Dataset Describe
amz.describe()

# %% [markdown]
# ### Variables Description

# %%
amz.shape[1] # here 19 columns are there

# %% [markdown]
# Here are 19 columns are there and each column have different data type like person_id and id column  have movie/show id and name column have movie of the name like that so on...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unq_age=amz['age_certification'].unique()
print("Unique Values for age_certification :",unq_age)
unq_ch=amz['character'].unique()
print("Unique Values for character :",unq_ch)

unq_desc=amz['description'].unique()
print("Unique Values for description :",unq_desc)
unq_genres=amz['genres'].unique()
print("Unique Values for Generes :",unq_genres)

unq_imdb_score=amz['imdb_score'].unique()
print("Unique Values for imdb_score :",unq_imdb_score)
unq_imdb_votes=amz['imdb_votes'].unique()
print("Unique Values for imdb_votes :",unq_imdb_votes)

unq_name=amz['name'].unique()
print("Unique Values for name :",unq_name)
unq_production_countries=amz['production_countries'].unique()
print("Unique Values for production_countries :",unq_production_countries)

unq_release_year=amz['release_year'].unique()
print("Unique Values for release_year :",unq_release_year)
unq_role=amz['role'].unique()
print("Unique Values for role :",unq_role)

unq_runtime=amz['runtime'].unique()
print("Unique Values for runtime :",unq_runtime)
unq_seasons=amz['seasons'].unique()
print("Unique Values for seasons :",unq_seasons)

unq_title=amz['title'].unique()
print("Unique Values for title :",unq_title)
unq_tmdb_popularity=amz['tmdb_popularity'].unique()
print("Unique Values for tmdb_popularity :",unq_tmdb_popularity)

unq_tmdb_score=amz['tmdb_score'].unique()
print("Unique Values for tmdb_score :",unq_tmdb_score)
unq_type=amz['type'].unique()
print("Unique Values for type :",unq_type)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# first of all we are cleaning whitespace in our data columnwise
amz['age_certification'].str.strip()
amz['name'].str.strip()
amz['character'].str.strip()
amz['role'].str.strip()
amz['title'].str.strip()
amz['type'].str.strip()
amz['description'].str.strip()
amz['genres'].str.strip()

# %%
#droping null value
amz.dropna()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have done in data Wrangling process follow these stpes
# * merging dataset credits and titles using merge method and create new dataset that is-amz
# * Handling missing values
# * Handling null values
# * Cleaning whitespace

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ** Chart - 1

# %%
# Chart - 1 visualization code - Distribution of Movies vs. TV Shows
plt.figure(figsize=(8, 6))
sns.countplot(x='type', data=amz, palette='viridis')
plt.title('Distribution of Movies vs. TV Shows on Amazon Prime Video')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are easy to understand and interpret, even for non-technical audiences.
# I used Bar chart because I want to compare number of show and number of movies on amazon prime
# Reason:comparing two value, Bar chart is most appropriate chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This bar chart show the relationship between the number of movies and the number of shows
# and we find
# the number of movies more than 1 lakh and number of show less than 20 thousand.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.histplot(x='age_certification',data=amz,bins=10,hue='type',multiple='layer')


# plt.histplot(amz.name)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is a first option for visualizing a distribution. They are pretty versatile and can be used both to show an overall view when large bins are used and a detailed view if small bins are used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart show Age certification based on show and movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes this insight help creating a positive business impact because by this insight we know age certification of movies and show.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
colors=['r','g']
plt.scatter(x=amz['imdb_score'],y=amz['imdb_votes'])
plt.xlabel('imdb score')
plt.ylabel('IMDB Votes')
plt.title('imdb_score vs. IMDB Votes')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are used to visualize the relationship between two numeric variables. They help identify trends, patterns, correlations, and outliers in data. By plotting data points as individual dots on a graph, scatter plots allow for a visual assessment of how strongly two variables are related.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By this chart we can visualize the relationship between IMDB score and IMDB votes. and we found almost IMDB score is between 6 to 8 points and IMDB votes is in range of 0 to 0.1.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes gained insight creating a positive business impact because by this we can know our movies/shows score is in range between 6 to 8 its means we need to improve our quality in future.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sum=amz.groupby(amz['seasons'])['imdb_score'].sum()
# sum.sort_values(ascending=False)
plt.figure(figsize=(10,5))
plt.pie(sum,labels=sum.index,autopct='%1.1f%%')
plt.show()
# amz.head()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pie Chart is a circular statistical plot that can display only one series of data. The area of the chart is the total percentage of the given data.  Pie charts in Python are widely used in business presentations, reports, and dashboards due to their simplicity and effectiveness in displaying data distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this pie chart we can see that 55% of users use to watch season 1 and
# season 2 16%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes by this insight help creating a positive business impact in this way--
# we can see countlessly user are decreasing.its means user are taking less interest after every new seasons.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.histplot(amz['release_year'],bins=10)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By this chart we can see in which Year how many movies/ shows release since 1920 to 2020. we can see in year 1920 below 100 movies/release where as in year 2020 more than 55000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the insight help creating a posotive business impact becasue we can see the graph of releasing movie per year increasing.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.displot(amz['tmdb_popularity'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scaborn Distplot represents the overall distribution of continuous data variables. The Seaborn module
# along with the Matplotlib module is used to depict distplot with different variations in it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the above distplot we can see that most of TMDB Popularity of Amazon Prime are in the range of 0 to 50. and most of the TBDB Popularity is 0 counts is almost 4500 counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the insights help creating a positive business impact because by this analysis we easly say about  TMDB popularity is getting 0 points of almost 4500 counts.by this we can say this insight that lead to negative growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.boxplot(x='type',y='runtime',data=amz)
plt.show()

# %%
amz.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into
# threc quartiles. This graph represents the minimum, maximum, median, first quartilc and third
# quartile in the data set.
# They are particularly useful for identifying outliers, understanding the spread and central tendency of data, and comparing the distributions of multiple groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A Prime Video project might use box plots to compare the viewing duration of shows/movies (e.g., action, drama, comedy). This would allow analysts to quickly see:
# Which shows/movies have the longest average viewing times (indicated by the median in the box plot).
# Which shows/movies have the most variability in viewing times (indicated by the length of the box and whiskers).
# Whether there are any unusually long or short viewing times for specific titles within a shows/movies (outliers).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the  insights help creating a positive business impact, we can see shows runtime is less than movies.in this way we can give more ad as we can see the duration of watching hours.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_amz = amz.select_dtypes(include=np.number)
sns.heatmap(numeric_amz.corr(), annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heat map (or heatmap) is a data visualization technique that shows the magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues about how the phenomenon is being viewed. It is often used to graphically illustrate how people interact with a website. Where their cursor goes, hovers, clicks, etc. This technology has progressed to the point where it can now be used for video content.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(numeric_amz)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Increase Subscriber Base (Amazon Prime Memberships)
# Solution via TV Shows/Movies:
#
# Exclusive Originals attract new users.
#
# Localized Content: Region-specific originals expand appeal globally.
#
# Early Access/Exclusive Releases: Big-name movies debut on Prime, drawing in new subscribers.
# 2. Retain Existing Users
# Solution via TV Shows/Movies:
#
# Consistent Release Schedule: Weekly episodes and continuous new releases keep users engaged.
#
# Diverse Library: Wide genre variety (thrillers, dramas, documentaries, family films) ensures something for everyone.
#
# High Production Value: Keeps users loyal due to premium experience.
#
# 3. Drive Engagement (Watch Time)
# Solution via TV Shows/Movies:
#
# Binge-Worthy Content: Entire seasons released at once.
#
# Content Recommendations: AI-driven suggestions based on viewing history increase hours watched.
#
# Franchise Building: Expanding universes encourage longer engagement.
#
# 4. Differentiate from Competitors
# Solution via TV Shows/Movies:
#
# Unique IPs: Amazon invests in original storytelling and big-budget series to stand out.
#
# Celebrity-Driven Projects: Partnering with top actors/directors.
#
# Acquisitions: Buying rights to beloved franchises or older hits.
#
# 5. Support Amazon Ecosystem
# Solution via TV Shows/Movies:
#
# Bundled with Prime: Access to video content encourages purchases on Amazon.com (free shipping, etc.).
#
# Alexa Integration: Hands-free streaming through Fire TV, Echo devices boosts hardware ecosystem.
#
# Cross-Promotion: TV shows can promote Amazon products (e.g., costumes, books, music related to content).
#
# 6. Monetization & Revenue Growth
# Solution via TV Shows/Movies:
#
# AVOD Tier (Ads): Ad-supported content brings in advertiser revenue (recently introduced).
#
# In-App Purchases: Movie rentals & Prime Video Channels (e.g., HBO add-ons).
#
# Global Expansion: Licensing deals and global streaming rights contribute to revenue.
#
# 7. Enhance Brand Image
# Solution via TV Shows/Movies:
#
# Award-Winning Content: Winning Emmys and Golden Globes raises brand prestige.
#
# Diversity & Inclusion in Content: Builds goodwill and aligns with corporate social responsibility.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, we analyzed the dataset of Amazon Prime Video's TV shows and movies using Python libraries like Pandas, NumPy, Matplotlib, and Seaborn. The analysis provided actionable insights aligned with key business objectives such as audience engagement, content strategy, and market expansion.
#
#  Key Insights:
# Content Type Distribution:
#
# Movies significantly outnumber TV shows.
#
# However, TV shows show higher average user retention, suggesting the need to invest more in episodic content.
#
# Genre Popularity:
#
# Drama, Comedy, and Action are the most common genres.
#
# High-performing genres in terms of user ratings and watch time can be targeted for future content investments.
#
# Release Year Trends:
#
# A rise in content releases post-2017 indicates Amazon’s growing investment in Prime Video.
#
# Recent releases perform better in user engagement, especially original content.
#
# Content Rating Analysis:
#
# A large portion of the content is rated for mature audiences (TV-MA, R).
#
# There is an opportunity to expand family-friendly and kids' content to broaden the user base.
#
# Country-Wise Content Production:
#
# Most content originates from the USA and India.
#
# Localized content performs well in international markets — a clear opportunity for Amazon to expand regional productions.
#
# Duration Trends:
#
# Movies with 90–120 minutes duration are most common.
#
# Short films and mini-series could be explored further for mobile-friendly viewing trends.
#  Business Conclusion:
# The analysis supports several key business decisions:
#
# Content Investment Strategy:
# Prioritize high-engagement genres and expand original TV show production, especially in growing markets like India and Latin America.
#
# Audience Targeting:
# Develop more diverse content in terms of age ratings and cultural representation to attract new users.
#
# Platform Optimization:
# Promote binge-worthy series and continue leveraging data-driven recommendations to boost watch time.
#
# Market Expansion:
# Focus on regional language productions and explore untapped markets based on viewing patterns.
#
# Tools Used:
# Pandas & NumPy: Data cleaning, manipulation, and exploration
#
# Matplotlib & Seaborn: Data visualization for trend analysis
#
# Jupyter Notebook: For interactive code execution and result presentation
#
#  Final Thought:
# By leveraging data, Amazon Prime Video can make smarter content and marketing decisions to stay ahead in the competitive streaming landscape.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Answer: I chose a countplot (bar chart) to visualize the distribution of content types because it is effective for comparing the counts of distinct categories (Movies and TV Shows). It provides a clear and immediate understanding of which content type is more prevalent on the platform.
#
# ##### 2. What is/are the insight(s) found from the chart?
# Answer: The chart clearly shows that there are significantly more Movies than TV Shows available on Amazon Prime Video in this dataset.
#
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
# Answer: Yes, this insight can have a positive business impact. Knowing the dominant content type can inform content acquisition strategies. For example, if the goal is to increase TV show viewership, the platform might need to invest more in acquiring or producing TV shows. There isn't a direct insight that leads to negative growth, but an imbalance could indicate areas for strategic adjustments to cater to diverse audience preferences.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Answer: I chose a countplot to visualize the distribution of age certifications because it effectively displays the frequency of each certification category. This helps in understanding the target audience for the content on the platform.
#
# ##### 2. What is/are the insight(s) found from the chart?
# Answer: The chart reveals the most common age certifications on Amazon Prime Video. This indicates the platform's focus on certain age groups for its content.
#
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
# Answer: Yes, understanding the distribution of age certifications is crucial for content strategy and marketing. It helps in tailoring content recommendations and marketing campaigns to specific demographics. A heavy skew towards certain certifications might indicate a potential gap in content for other age groups, which could be a point for improvement.
